# %% [markdown]
# # Corner Detection - Harris

# %% [markdown]
# ## Import all the necessary libraries

# %%
import cv2
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Read and display an image

# %%
img = cv2.imread("img/chessboard.jpg") # OpenCV image format is`BGR`.
img_corners = img.copy()
fig = plt.figure(figsize=(10, 5))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## Convert an image into grayscale

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')

# %% [markdown]
# ## Apply Harris Corner
#
# `cv2.cornerHarris(img, blockSize, ksize, k)`
#
# - img: Input image, it should be grayscale and float32 type.
# - blockSize: It is the size of neighbourhood considered for corner detection.
# - ksize: Aperture parameter of Sobel derivative used.
# - k: Harris detector free parameter in the equation.

# %%
corners = cv2.cornerHarris(gray, 5, 3, 0.1)
plt.imshow(corners, cmap='gray')

# %% [markdown]
# ## Dilate

# %%
corners_dilate = cv2.dilate(corners, np.ones((8,8),np.uint8), iterations = 1)
plt.imshow(corners_dilate, cmap='gray')

# %% [markdown]
# ## Apply corner to the original image

# %%
print("origin_image_shape: ", img_corners.shape)
print("corners_dilate_shape: ", corners_dilate.shape)
print("corners_dilate_max: ", corners_dilate.max())

# If pixel value is greater than a threshold, return true and mark it as green
img_corners[corners_dilate > 0.01 * corners_dilate.max()] = [0, 255, 0]
plt.imshow(img_corners)
# Out:
# origin_image_shape:  (481, 481, 3)
# corners_dilate_shape:  (481, 481)
# corners_dilate_max:  0.01771874

# %%
#import sys
#np.set_printoptions(threshold=sys.maxsize)
img_corners
# Out:
# array([[[ 36,  36,  36],
#         [ 34,  34,  34],
#         [ 33,  33,  33],
#         ...,
#         [ 83,  83,  83],
#         [ 84,  84,  84],
#         [ 57,  57,  57]],
#
#        [[ 35,  35,  35],
#         [ 33,  33,  33],
#         [ 32,  32,  32],
#         ...,
#         [217, 217, 217],
#         [215, 215, 215],
#         [177, 177, 177]],
#
#        [[ 28,  28,  28],
#         [ 25,  25,  25],
#         [ 24,  24,  24],
#         ...,
#         [246, 246, 246],
#         [243, 243, 243],
#         [200, 200, 200]],
#
#        ...,
#
#        [[251, 251, 251],
#         [255, 255, 255],
#         [251, 251, 251],
#         ...,
#         [ 24,  24,  24],
#         [ 24,  24,  24],
#         [ 25,  25,  25]],
#
#        [[251, 251, 251],
#         [255, 255, 255],
#         [251, 251, 251],
#         ...,
#         [ 24,  24,  24],
#         [ 24,  24,  24],
#         [ 25,  25,  25]],
#
#        [[251, 251, 251],
#         [255, 255, 255],
#         [252, 252, 252],
# ...
